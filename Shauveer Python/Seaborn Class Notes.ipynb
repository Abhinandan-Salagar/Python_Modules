# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### In-build Datasets in seaborn

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Regression Plot
#
# This plot shows the line of regression (direction of relationship) between 2 numerical cols

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# if it was suppose to be done using matplotlib
# plt.scatter()
# plt.xlabel
# ylabe
# plt.line(jbeg)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Relational Plot
# Scatter plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')  # hue will create color filters

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')  # style will create markerstyle filters

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',size='size')  # size will create small to big markersizes

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',size='size',col='day')  # col will divide the plots into categories

# %% [markdown]
# ### Loading another dataset

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # barplot

# %%
sns.barplot(x='who',y='survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='who', ylabel='survived'>

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill',data=tips)  # swarm style

# %%
sns.catplot(x='day',y='total_bill',data=tips,jitter=False)  # will put all the data points into a single line

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='violin')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='box')

# %% [markdown]
# # Distribution plot

# %%
sns.distplot(x=tips['total_bill'],kde=True)
# Out:
# C:\Users\SAUVEER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # pairplots

# %%
sns.pairplot(tips)
# same col -> histogram
# diff col -> scatterplot

# %% [markdown]
# # Heatmaps
#
# visualize matrices as heat(color intensity) cells

# %%
cormat = tips.corr()  # correlation matrix
cormat
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(cormat,annot=True,fmt='.3f',cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# # Doubts

# %%
# zip - paring the corresponding elements of 2 tuple objects
a = ('India','USA','China')
b = (3,5,7)
z = zip(a,b)
z = list(z)
print(z)
# Out:
# [('India', 3), ('USA', 5), ('China', 7)]

# %%
# unzip(z)
first_element = [i for i,j in z]
second_element = [j+1 for i,j in z]
print(first_element)
print(second_element)
# Out:
# ['India', 'USA', 'China']
# [4, 6, 8]

# %%
list1 = ['eat','sleep','repeat']

for ele in enumerate(list1):
    print(ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')

# %%
for ele in list1:
    print(ele)
# Out:
# eat
# sleep
# repeat
