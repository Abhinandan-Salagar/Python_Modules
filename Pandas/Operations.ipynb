# %% [markdown]
# # Operations
#
# There are lots of operations with pandas that will be really useful to you, but don't fall into any distinct category. Let's show them here in this lecture:

# %%
import pandas as pd
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_colwidth", 2000)
# pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)

df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Info on Unique Values for a Column:

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.drop_duplicates(subset="col2",
                     keep="last", inplace=True)
df.head()
# Out:
#    col1  col2 col3
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sample()
# Out:
#    col1  col2 col3
# 2     3   666  ghi

# %%
df1=pd.read_csv("Salaries.csv")
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
import pandas as pd

data = {
    "Brand": ["Ford", "Ford", "Ford"],
    "Model": ["Sierra", "F-150", "Mustang"],
    "Typ": ["2.0 GL", "Raptor", ["Mach-E", "Mach-1"]]
}
df = pd.DataFrame(data)

newdf = df.explode('Typ')
newdf
# Out:
#   Brand    Model               Typ
# 0  Ford   Sierra            2.0 GL
# 1  Ford    F-150            Raptor
# 2  Ford  Mustang  [Mach-E, Mach-1]

# %%
import pandas as pd

data = {
    "firstname": ["Sally", "Mary", "John"],
    "age": [50, 40, 30]
}

df = pd.DataFrame(data)

for x, y in df.items():
  print(x)
  print(y)
# Out:
# firstname
# 0    Sally
# 1     Mary
# 2     John
# Name: firstname, dtype: object
# age
# 0    50
# 1    40
# 2    30
# Name: age, dtype: int64

# %%
df1.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
pd.set_option('display.min_rows', 500)  # <-add this!
pd.set_option('display.max_rows', 500)
pd.set_option('max_colwidth', 400)
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
df1['JobTitle'].nunique()
# Out:
# 2159

# %%
df1['JobTitle'].unique()

# %%
df1['JobTitle'].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df1.loc[df1["EmployeeName"]=="GARY JIMENEZ" , ["JobTitle","BasePay"]]="kuch bhi",000000
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                        kuch bhi
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1       0.00    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df1['JobTitle'].value_counts()

# %%
df[["EmployeeName","TotalPay"]]

# %%
col=df[["EmployeeName","TotalPay"]].values.ravel()
a=pd.unique(col)
a

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Selecting Data

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
newdf = df1[(df1['BasePay'] > 99000) & (df1['BasePay'] < 110000)]
len(newdf)
# Out:
# 8727

# %%
newdf.head()
# Out:
#     Id      EmployeeName                            JobTitle    BasePay  \
# 11  12  PATRICIA JACKSON     CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 33  34        JOHN TURSI  INSPECTOR III, (POLICE DEPARTMENT)  104861.39
# 35  36        KHOA TRINH   ELECTRONIC MAINTENANCE TECHNICIAN  101953.20
# 61  62        ANNA BROWN     CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 91  92     DONNA MEIXNER     CAPTAIN III (POLICE DEPARTMENT)  102722.40
#
#     OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 11     87082.62  110804.30       NaN  297608.92         297608.92  2011
# 33     50227.61  103499.39       NaN  258588.39         258588.39  2011
# 35    139102.95   16483.94       NaN  257540.09         257540.09  2011
# 61      7437.00  128543.64       NaN  238551.88         238551.88  2011
# 91      7437.00  118456.21       NaN  228615.61         228615.61  2011
#
#     Notes         Agency  Status
# 11    NaN  San Francisco     NaN
# ...

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
def to_lower_convert(ename):
    return ename.lower()

# %%
df1["EmployeeName_cleaned"]=df1['EmployeeName'].apply(to_lower_convert)
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     nathaniel ford  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       gary jimenez                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     albert pardini                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  christopher chong            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    patrick gardner    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status EmployeeName_cleaned
# ...

# %%
df1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status', 'EmployeeName_cleaned'],
#       dtype='object')

# %%
df=df1[['Id', 'OtherPay','BasePay', 'OvertimePay',
       'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year','JobTitle', 'Notes', 'Agency',
       'Status', 'EmployeeName_cleaned','EmployeeName']]

# %%
df.head()
# Out:
#    Id   OtherPay    BasePay  OvertimePay  Benefits   TotalPay  \
# 0   1  400184.25  167411.18         0.00       NaN  567595.43
# 1   2  137811.38  155966.02    245131.88       NaN  538909.28
# 2   3   16452.60  212739.13    106088.18       NaN  335279.91
# 3   4  198306.90   77916.00     56120.71       NaN  332343.61
# 4   5  182234.59  134401.60      9737.00       NaN  326373.19
#
#    TotalPayBenefits  Year                                        JobTitle  \
# 0         567595.43  2011  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1         538909.28  2011                 CAPTAIN III (POLICE DEPARTMENT)
# 2         335279.91  2011                 CAPTAIN III (POLICE DEPARTMENT)
# 3         332343.61  2011            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         326373.19  2011    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#    Notes         Agency  Status EmployeeName_cleaned       EmployeeName
# 0    NaN  San Francisco     NaN       nathaniel ford     nathaniel ford
# ...

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     nathaniel ford  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       gary jimenez                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     albert pardini                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  christopher chong            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    patrick gardner    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status EmployeeName_cleaned
# ...

# %%
def find_length(name):
    return len(name)

# %%
def times2(cols):
    x=cols[0]
    y=cols[1]
    return x*y

# %%
times2(4,4)
# Out:
# 16

# %%
df1["TotalPay_revised"]=df1[['TotalPay','BasePay']].apply(times2)
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                        kuch bhi
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1       0.00    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  TotalPay_revised
# ...

# %%
df1["length_of_names"]=df1['EmployeeName'].apply(find_length)
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                        kuch bhi
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1       0.00    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
# ...

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     nathaniel ford  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       gary jimenez                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     albert pardini                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  christopher chong            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    patrick gardner    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status EmployeeName_cleaned
# ...

# %%
df1.sort_values(by='EmployeeName',ascending=True) #inplace=False by default
# Out:
#             Id           EmployeeName                   JobTitle   BasePay  \
# 102843  102844      a bernard  fatooh  Sheriff's Property Keeper  23908.50
# 140525  140526       a bernard fatooh  Sheriff's Property Keeper  24061.35
# 29353    29354       a bernard fatooh  SHERIFF'S PROPERTY KEEPER  19969.37
# 66371    66372       a bernard fatooh  Sheriff's Property Keeper  18472.35
# 28469    28470  a elizabeth marchasin            PRINCIPAL CLERK  23591.80
# ...        ...                    ...                        ...       ...
# 22350    22351              zuren mei                  CUSTODIAN  48472.40
# 93463    93464            zuri  jones   Deputy Probation Officer  71986.90
# 132614  132615             zuri jones   Deputy Probation Officer  66667.54
# 17185    17186             zuri jones   DEPUTY PROBATION OFFICER  70888.04
# 49185    49186             zuri jones   Deputy Probation Officer  86588.52
#
# ...

# %%
df1.head()
# Out:
#             Id          EmployeeName                      JobTitle    BasePay  \
# 72925    72926        Gregory P Suhr               Chief of Police  319275.01
# 110532  110533            Amy P Hart             Asst Med Examiner  318835.49
# 72929    72930         Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 72926    72927  Joanne M Hayes-White        Chief, Fire Department  313686.01
# 72931    72932     Harlan L Kelly-Jr   Executive Contract Employee  313312.52
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 72925          0.00  20007.06  86533.21  339282.07         425815.28  2013
# 110532     10712.95  60563.54  89540.23  390111.98         479652.21  2014
# 72929          0.00      0.00  82849.66  315572.01         398421.67  2013
# 72926          0.00  23236.00  85431.39  336922.01         422353.40  2013
# 72931          0.00      0.00  82319.51  313312.52         395632.03  2013
#
# ...

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
#Select from DataFrame using criteria from multiple columns
newdf = df[(df['col1']>2) | (df['col2']==444)]

# %%
newdf
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return x*2

# %%
def to_upper(x):
    return x.upper()

# %%
def find_length(x):
    return len(x)

# %%
df['col3']=df['col3'].apply(to_upper)
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  ABC
# 1     2   555  DEF
# 2     3   666  GHI
# 3     4   444  XYZ

# %%
df['col2'].apply(times2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df["length_of_col"]=df['col3'].apply(find_length)
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col1'].sum()
# Out:
# 10

# %% [markdown]
# ** Get column and index names: **

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values(by='col2') #inplace=False by default
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df_new=df["col1"].sort_values(ascending=False)
df_new
# Out:
# 3    4
# 2    3
# 1    2
# 0    1
# Name: col1, dtype: int64

# %%
df.sort_values(by='col3',ascending=False) #inplace=False by default
# Out:
#    col1  col2 col3
# 3     4   444  xyz
# 2     3   666  ghi
# 1     2   555  def
# 0     1   444  abc

# %%
df.sort_values(by='col3',ascending=True) #inplace=False by default
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ** Filling in NaN values with something else: **

# %%
import numpy as np

# %%
import numpy as np
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.isnull().sum()
# Out:
# col1    1
# col2    1
# col3    0
# dtype: int64

# %%
# str_cols = ['Name','City']
str_cols = df.columns[df.dtypes==object]
df[str_cols] = df[str_cols].fillna('.')
df = df.fillna(0)
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df["col2"]=df["col2"].fillna(df["col2"].mean())
df.head()
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.head()
# Out:
# 0    555.0
# 1    555.0
# 2    666.0
# 3    444.0
# Name: col2, dtype: float64

# %%
df.fillna({'col1':0,'col2':0},inplace=True)

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    0.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   0.0  444.0  xyz

# %%
# importing pandas as pd
import pandas as pd
import numpy as np
   
# creating a dataframe
df = pd.DataFrame({'A': ['John', 'Boby', 'Mina', 'Peter', 'Nicky'],
      'B': ['Masters', 'Graduate', 'Graduate', 'Masters', 'Graduate'],
      'C': [27, 23, 21, 23, 24]})
   
df.head()
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
table = pd.pivot_table(df,index=['A','B','C'])
  
table
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Boby, Graduate, 23), (John, Masters, 27), (Mina, Graduate, 21), (Nicky, Graduate, 24), (Peter, Masters, 23)]

# %%
df.head()
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
# Creates a pivot table dataframe
table = pd.pivot_table(df, values ='A', index =['B', 'C'],
						columns =['B'], aggfunc = np.sum)

table
# Out:
# B           Graduate Masters
# B        C
# Graduate 21     Mina     NaN
#          23     Boby     NaN
#          24    Nicky     NaN
# Masters  23      NaN   Peter
#          27      NaN    John

# %% [markdown]
# # Great Job!
